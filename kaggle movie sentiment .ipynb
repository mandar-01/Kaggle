# %%
import pandas as pd
from bs4 import BeautifulSoup
import re
import nltk
from nltk.corpus import stopwords
#nltk.download()
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
train = pd.read_csv("train.tsv",header=0,delimiter="\t",quoting=3)
print train.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
def clean_text(example1):
    example1 = BeautifulSoup(example1)
    example1 = re.sub("[^a-zA-Z]"," ",example1.get_text())
    example1 = example1.lower()
    words = example1.split()
    stops = set(stopwords.words("english"))
    words = [w for w in words if not w in stops]
    return( " ".join(words))

# %%
print clean_text(train["Phrase"][0])
# Out:
# series escapades demonstrating adage good goose also good gander occasionally amuses none amounts much story

# %%
num_reviews = train["PhraseId"].size
cleaned_review = []
for i in xrange(0,num_reviews):
    cleaned_review.append(clean_text(train["Phrase"][i]))
print cleaned_review[0]
# Out:
# C:\ProgramFiles\Anaconda2\lib\site-packages\bs4\__init__.py:219: UserWarning: "." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\ProgramFiles\Anaconda2\lib\site-packages\bs4\__init__.py:219: UserWarning: "..." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# series escapades demonstrating adage good goose also good gander occasionally amuses none amounts much story

# %%
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 
train_data_features = vectorizer.fit_transform(cleaned_review)
train_data_features = train_data_features.toarray()

# %%
vocab = vectorizer.get_feature_names()
# Out:
# [u'abandon', u'ability', u'able', u'absolute', u'absolutely', u'absorbing', u'abstract', u'absurd', u'absurdity', u'abundant', u'abuse', u'academy', u'accent', u'accents', u'accept', u'acceptable', u'access', u'accessible', u'accident', u'accomplished', u'accomplishments', u'account', u'accurate', u'accurately', u'acerbic', u'ache', u'achieve', u'achievement', u'achieves', u'achingly', u'acknowledges', u'across', u'act', u'acted', u'acting', u'action', u'actions', u'actor', u'actors', u'actress', u'actresses', u'acts', u'actual', u'actually', u'ad', u'adam', u'adams', u'adaptation', u'adapted', u'add', u'added', u'addition', u'adds', u'adequate', u'adequately', u'admirable', u'admire', u'admission', u'admit', u'admittedly', u'adolescence', u'adolescent', u'adrenaline', u'adult', u'adults', u'advantage', u'adventure', u'adventures', u'adventurous', u'advice', u'affair', u'affected', u'affecting', u'affection', u'affirming', u'affleck', u'afraid', u'african', u'afterlife', u'afternoon', u'age', u'aged', u'agency', u'agent', u'ages', u'aggrandizing', u'aggressive', u'aging', u'ago', u'agonizing', u'ah', u'ahead', u'ai', u'aid', u'aids', u'aim', u'aimed', u'aimless', u'aims', u'air', u'alabama', u'albeit', u'album', u'alert', u'alfred', u'alice', u'alien', u'alienation', u'aliens', u'alike', u'alive', u'allegory', u'allen', u'allow', u'allowed', u'allows', u'alluring', u'almost', u'alone', u'along', u'already', u'also', u'alternate', u'alternately', u'alternative', u'although', u'altman', u'